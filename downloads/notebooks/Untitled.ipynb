# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.DataFrame([range(10000), range(10000)]).transpose().plot.hexbin(x=0, y=1)

# %%
ax = _

# %%
[str(s) for s in ax.xaxis.get_ticklabels()]
# Out:
# ["Text(0,0,'')",
#  "Text(0,0,'0')",
#  "Text(2000,0,'2000')",
#  "Text(4000,0,'4000')",
#  "Text(6000,0,'6000')",
#  "Text(8000,0,'8000')",
#  "Text(10000,0,'10000')",
#  "Text(0,0,'')"]

# %%
l = ax.xaxis.get_ticklabels()[0]

# %%
l.get_color()
# Out:
# 'k'

# %%
l.get_fontsize()
# Out:
# 10.0

# %%
l.get_text()
# Out:
# ''

# %%
[str(s) for s in ax.yaxis.get_ticklabels()]
# Out:
# ["Text(0,0,'')",
#  "Text(0,0,'0')",
#  "Text(0,2000,'2000')",
#  "Text(0,4000,'4000')",
#  "Text(0,6000,'6000')",
#  "Text(0,8000,'8000')",
#  "Text(0,10000,'10000')",
#  "Text(0,0,'')"]

# %%
fig = ax.get_figure()

# %%
fig.tight_layout()

# %%
fig
